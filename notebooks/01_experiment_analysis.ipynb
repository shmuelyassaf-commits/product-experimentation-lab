# %% [markdown]
# # Product Experimentation Lab
#
# This notebook documents the decision workflow: trust checks, retention inference, engagement guardrails, and a product recommendation.

# %%
from pathlib import Path
import pandas as pd
from src.experiment import analyze

path = Path('../data/raw/cookie_cats.csv')
data = pd.read_csv(path)
results = analyze(data)
results['decision']

# %% [markdown]
# ## How to read the output
#
# Do not stop at p-value. Check sample quality, confidence intervals, practical lift, and guardrails before recommending a rollout.
